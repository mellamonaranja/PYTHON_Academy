# %%
import pandas as pd

# %%
df1 = pd.read_csv('samplefile1.csv')

# %%
df1
# Out:
#    c1    c2     c3
# 0   1  1.11    one
# 1   2  2.22    two
# 2   3  3.33  three

# %%
df2 = pd.read_csv('samplefile2.csv')

# %%
df2
# Out:
#    1  1.11    one
# 0  2  2.22    two
# 1  3  3.33  three

# %%
df2 = pd.read_csv('samplefile2.csv', 
                  names=['c1', 'c2', 'c3'])

# %%
df2
# Out:
#    c1    c2     c3
# 0   1  1.11    one
# 1   2  2.22    two
# 2   3  3.33  three

# %%
df3 = pd.read_csv('samplefile1.csv', index_col='c1')

# %%
df3
# Out:
#       c2     c3
# c1
# 1   1.11    one
# 2   2.22    two
# 3   3.33  three

# %%
df3 = pd.read_csv('samplefile1.csv', index_col=0)

# %%
df3
# Out:
#       c2     c3
# c1
# 1   1.11    one
# 2   2.22    two
# 3   3.33  three

# %%
df4 = pd.read_csv('samplefile3.csv')

# %%
df4
# Out:
#    c1    c2     c3
# 0   1  1.11    NaN
# 1   2   NaN    two
# 2  누락  3.33  three

# %%
df4 = pd.read_csv('samplefile3.csv', encoding='utf-8')

# %%
df4
# Out:
#    c1    c2     c3
# 0   1  1.11    NaN
# 1   2   NaN    two
# 2  누락  3.33  three

# %%
df = pd.read_csv('samplefile4.csv')

# %%
df
# Out:
#    Unnamed: 0  c1    c2     c3
# 0           0   1  1.11    one
# 1           1   2  2.22    two
# 2           2   3  3.33  three

# %%
df = pd.read_csv('samplefile5.csv')

# %%
df
# Out:
#         |c1|c2|c3
# 0    0|1|1.11|one
# 1    1|2|2.22|two
# 2  2|3|3.33|three

# %%
df = pd.read_csv('samplefile5.csv', delimiter='|')

# %%
df
# Out:
#    Unnamed: 0  c1    c2     c3
# 0           0   1  1.11    one
# 1           1   2  2.22    two
# 2           2   3  3.33  three

# %%
df4
# Out:
#    c1    c2     c3
# 0   1  1.11    NaN
# 1   2   NaN    two
# 2  누락  3.33  three

# %%
df4.to_csv('samplefile6.csv', na_rep='누락')

# %%
df = pd.read_csv('samplefile6.csv')

# %%
df
# Out:
#    Unnamed: 0  c1    c2     c3
# 0           0   1  1.11     누락
# 1           1   2    누락    two
# 2           2  누락  3.33  three

# %%
df2
# Out:
#    c1    c2     c3
# 0   1  1.11    one
# 1   2  2.22    two
# 2   3  3.33  three

# %%
df2.to_csv('samplefile7.csv', index=False, header=False)

# %%
df = pd.read_csv('samplefile7.csv')

# %%
df
# Out:
#    1  1.11    one
# 0  2  2.22    two
# 1  3  3.33  three

# %%
df = pd.read_csv('samplefile7.csv', header=None)

# %%
df
# Out:
#    0     1      2
# 0  1  1.11    one
# 1  2  2.22    two
# 2  3  3.33  three

# %%
df = pd.read_csv('samplefile7.csv', 
                 names=['C1', 'C2', 'C3'])

# %%
df
# Out:
#    C1    C2     C3
# 0   1  1.11    one
# 1   2  2.22    two
# 2   3  3.33  three

# %%
df = pd.read_csv('http://codedragon.tistory.com/attachment/cfile9.uf@99111B405B286CDD0EC8B9.csv')

# %%
df
# Out:
#    survived pclass     sex  age sibsp parch     fare embarked   class    who  \
# 0         0      3    male   22     1     0     7.25        S   Third    man
# 1         1      1  female   38     1     0  71.2833        C   First  woman
# 2         1      3  female   26     0     0    7.925        S   Third  woman
# 3         1      1  female   35     1     0     53.1        S   First  woman
# 4         0      3    male   35     0     0     8.05        S   Third    man
# ..      ...    ...     ...  ...   ...   ...      ...      ...     ...    ...
# 56        0      2    male   27     0     0       13        S  Second    man
# 57        1      1  female   19     0     0       30        S   First  woman
# 58        0      3  female  NaN     1     2    23.45        S   Third  woman
# 59        1      1    male   26     0     0       30        C   First    man
# 60        0      3    male   32     0     0     7.75        Q   Third    man
#
#    adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#   survived pclass     sex age sibsp parch     fare embarked  class    who  \
# 0        0      3    male  22     1     0     7.25        S  Third    man
# 1        1      1  female  38     1     0  71.2833        C  First  woman
# 2        1      3  female  26     0     0    7.925        S  Third  woman
# 3        1      1  female  35     1     0     53.1        S  First  woman
# 4        0      3    male  35     0     0     8.05        S  Third    man
#
#   adult_male deck  embark_town alive  alone
# 0       TRUE  NaN  Southampton    no  FALSE
# 1      FALSE    C    Cherbourg   yes  FALSE
# 2      FALSE  NaN  Southampton   yes   TRUE
# 3      FALSE    C  Southampton   yes  FALSE
# 4       TRUE  NaN  Southampton    no   TRUE

# %%
df.tail()
# Out:
#    survived pclass     sex  age sibsp parch   fare embarked   class    who  \
# 56        0      2    male   27     0     0     13        S  Second    man
# 57        1      1  female   19     0     0     30        S   First  woman
# 58        0      3  female  NaN     1     2  23.45        S   Third  woman
# 59        1      1    male   26     0     0     30        C   First    man
# 60        0      3    male   32     0     0   7.75        Q   Third    man
#
#    adult_male deck  embark_town alive  alone
# 56       TRUE  NaN  Southampton    no   TRUE
# 57      FALSE    B  Southampton   yes   TRUE
# 58      FALSE  NaN  Southampton    no  FALSE
# 59       TRUE    C    Cherbourg   yes   TRUE
# 60       TRUE  NaN          NaN   NaN    NaN

# %%
df.tail(10)
# Out:
#    survived pclass     sex  age sibsp parch     fare embarked   class    who  \
# 51        0      3    male   33     0     0   7.8958        S   Third    man
# 52        0      3  female   22     0     0  10.5167        S   Third  woman
# 53        0      2    male   28     0     0     10.5        S  Second    man
# 54        0      3    male   25     0     0     7.05        S   Third    man
# 55        0      3  female   39     0     5   29.125        Q   Third  woman
# 56        0      2    male   27     0     0       13        S  Second    man
# 57        1      1  female   19     0     0       30        S   First  woman
# 58        0      3  female  NaN     1     2    23.45        S   Third  woman
# 59        1      1    male   26     0     0       30        C   First    man
# 60        0      3    male   32     0     0     7.75        Q   Third    man
#
#    adult_male deck  embark_town alive  alone
# 51       TRUE  NaN  Southampton    no   TRUE
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=61, step=1)

# %%
pd.date_range('1/1/2020', periods=8)
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
index = pd.date_range('1/1/2020', periods=8)

# %%
index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np

# %%
np.random.rand(8, 3)
# Out:
# array([[0.40320743, 0.32791258, 0.91479789],
#        [0.80423237, 0.78156501, 0.30454504],
#        [0.79599015, 0.19333864, 0.29760599],
#        [0.5347138 , 0.54252162, 0.78983816],
#        [0.62970496, 0.86294953, 0.72322641],
#        [0.3135141 , 0.94707021, 0.39071587],
#        [0.39596552, 0.51290057, 0.7652146 ],
#        [0.00811133, 0.59817693, 0.42959714]])

# %%
df = pd.DataFrame(np.random.rand(8,3),
                 columns=list('ABC'),
                 index=index)

# %%
df
# Out:
#                    A         B         C
# 2020-01-01  0.002968  0.885920  0.103223
# 2020-01-02  0.257503  0.989544  0.671397
# 2020-01-03  0.698028  0.476421  0.416134
# 2020-01-04  0.204280  0.717197  0.954184
# 2020-01-05  0.116106  0.830741  0.175403
# 2020-01-06  0.664703  0.746365  0.339981
# 2020-01-07  0.380028  0.567562  0.600454
# 2020-01-08  0.579048  0.807169  0.661439

# %%
df['B']
# Out:
# 2020-01-01    0.885920
# 2020-01-02    0.989544
# 2020-01-03    0.476421
# 2020-01-04    0.717197
# 2020-01-05    0.830741
# 2020-01-06    0.746365
# 2020-01-07    0.567562
# 2020-01-08    0.807169
# Freq: D, Name: B, dtype: float64

# %%
df.loc['2020-01-08']
# Out:
# A    0.579048
# B    0.807169
# C    0.661439
# Name: 2020-01-08 00:00:00, dtype: float64

# %%
df['B']
# Out:
# 2020-01-01    0.885920
# 2020-01-02    0.989544
# 2020-01-03    0.476421
# 2020-01-04    0.717197
# 2020-01-05    0.830741
# 2020-01-06    0.746365
# 2020-01-07    0.567562
# 2020-01-08    0.807169
# Freq: D, Name: B, dtype: float64

# %%
df['C'] > 0.4
# Out:
# 2020-01-01    False
# 2020-01-02     True
# 2020-01-03     True
# 2020-01-04     True
# 2020-01-05    False
# 2020-01-06    False
# 2020-01-07     True
# 2020-01-08     True
# Freq: D, Name: C, dtype: bool

# %%
df2 = df[df['C'] > 0.4]

# %%
df2
# Out:
#                    A         B         C
# 2020-01-02  0.257503  0.989544  0.671397
# 2020-01-03  0.698028  0.476421  0.416134
# 2020-01-04  0.204280  0.717197  0.954184
# 2020-01-07  0.380028  0.567562  0.600454
# 2020-01-08  0.579048  0.807169  0.661439

# %%
df2.T
# Out:
#    2020-01-02  2020-01-03  2020-01-04  2020-01-07  2020-01-08
# A    0.257503    0.698028    0.204280    0.380028    0.579048
# B    0.989544    0.476421    0.717197    0.567562    0.807169
# C    0.671397    0.416134    0.954184    0.600454    0.661439

# %%
df
# Out:
#                    A         B         C
# 2020-01-01  0.002968  0.885920  0.103223
# 2020-01-02  0.257503  0.989544  0.671397
# 2020-01-03  0.698028  0.476421  0.416134
# 2020-01-04  0.204280  0.717197  0.954184
# 2020-01-05  0.116106  0.830741  0.175403
# 2020-01-06  0.664703  0.746365  0.339981
# 2020-01-07  0.380028  0.567562  0.600454
# 2020-01-08  0.579048  0.807169  0.661439

# %%
df['A']
# Out:
# 2020-01-01    0.002968
# 2020-01-02    0.257503
# 2020-01-03    0.698028
# 2020-01-04    0.204280
# 2020-01-05    0.116106
# 2020-01-06    0.664703
# 2020-01-07    0.380028
# 2020-01-08    0.579048
# Freq: D, Name: A, dtype: float64

# %%
df['B']
# Out:
# 2020-01-01    0.885920
# 2020-01-02    0.989544
# 2020-01-03    0.476421
# 2020-01-04    0.717197
# 2020-01-05    0.830741
# 2020-01-06    0.746365
# 2020-01-07    0.567562
# 2020-01-08    0.807169
# Freq: D, Name: B, dtype: float64

# %%
df['D'] = df['A'] / df['B']

# %%
df
# Out:
#                    A         B         C         D
# 2020-01-01  0.002968  0.885920  0.103223  0.003350
# 2020-01-02  0.257503  0.989544  0.671397  0.260224
# 2020-01-03  0.698028  0.476421  0.416134  1.465150
# 2020-01-04  0.204280  0.717197  0.954184  0.284831
# 2020-01-05  0.116106  0.830741  0.175403  0.139762
# 2020-01-06  0.664703  0.746365  0.339981  0.890587
# 2020-01-07  0.380028  0.567562  0.600454  0.669580
# 2020-01-08  0.579048  0.807169  0.661439  0.717382

# %%
np.sum(df, axis=1)
# Out:
# 2020-01-01    0.995460
# 2020-01-02    2.178667
# 2020-01-03    3.055732
# 2020-01-04    2.160493
# 2020-01-05    1.262012
# 2020-01-06    2.641636
# 2020-01-07    2.217624
# 2020-01-08    2.765038
# Freq: D, dtype: float64

# %%
df['E'] = np.sum(df, axis=1)

# %%
df
# Out:
#                    A         B         C         D         E
# 2020-01-01  0.002968  0.885920  0.103223  0.003350  0.995460
# 2020-01-02  0.257503  0.989544  0.671397  0.260224  2.178667
# 2020-01-03  0.698028  0.476421  0.416134  1.465150  3.055732
# 2020-01-04  0.204280  0.717197  0.954184  0.284831  2.160493
# 2020-01-05  0.116106  0.830741  0.175403  0.139762  1.262012
# 2020-01-06  0.664703  0.746365  0.339981  0.890587  2.641636
# 2020-01-07  0.380028  0.567562  0.600454  0.669580  2.217624
# 2020-01-08  0.579048  0.807169  0.661439  0.717382  2.765038

# %%
df['A']
# Out:
# 2020-01-01    0.002968
# 2020-01-02    0.257503
# 2020-01-03    0.698028
# 2020-01-04    0.204280
# 2020-01-05    0.116106
# 2020-01-06    0.664703
# 2020-01-07    0.380028
# 2020-01-08    0.579048
# Freq: D, Name: A, dtype: float64

# %%
df.sub(df['A'], axis=0)
# Out:
#               A         B         C         D         E
# 2020-01-01  0.0  0.882952  0.100255  0.000382  0.992493
# 2020-01-02  0.0  0.732041  0.413895  0.002721  1.921165
# 2020-01-03  0.0 -0.221607 -0.281894  0.767122  2.357705
# 2020-01-04  0.0  0.512917  0.749904  0.080551  1.956213
# 2020-01-05  0.0  0.714635  0.059297  0.023656  1.145906
# 2020-01-06  0.0  0.081662 -0.324722  0.225884  1.976933
# 2020-01-07  0.0  0.187534  0.220426  0.289552  1.837596
# 2020-01-08  0.0  0.228121  0.082391  0.138333  2.185990

# %%
df = df.div(df['C'], axis=0)

# %%
df
# Out:
#                    A         B    C         D         E
# 2020-01-01  0.028751  8.582606  1.0  0.032453  9.643810
# 2020-01-02  0.383532  1.473858  1.0  0.387585  3.244975
# 2020-01-03  1.677411  1.144874  1.0  3.520860  7.343145
# 2020-01-04  0.214089  0.751634  1.0  0.298508  2.264230
# 2020-01-05  0.661938  4.736186  1.0  0.796804  7.194928
# 2020-01-06  1.955119  2.195314  1.0  2.619523  7.769957
# 2020-01-07  0.632901  0.945221  1.0  1.115123  3.693244
# 2020-01-08  0.875437  1.220323  1.0  1.084577  4.180337

# %%
df.to_csv('ex13.csv')

# %%
df = pd.read_csv('ex13.csv')

# %%
df
# Out:
#    Unnamed: 0         A         B    C         D         E
# 0  2020-01-01  0.028751  8.582606  1.0  0.032453  9.643810
# 1  2020-01-02  0.383532  1.473858  1.0  0.387585  3.244975
# 2  2020-01-03  1.677411  1.144874  1.0  3.520860  7.343145
# 3  2020-01-04  0.214089  0.751634  1.0  0.298508  2.264230
# 4  2020-01-05  0.661938  4.736186  1.0  0.796804  7.194928
# 5  2020-01-06  1.955119  2.195314  1.0  2.619523  7.769957
# 6  2020-01-07  0.632901  0.945221  1.0  1.115123  3.693244
# 7  2020-01-08  0.875437  1.220323  1.0  1.084577  4.180337
