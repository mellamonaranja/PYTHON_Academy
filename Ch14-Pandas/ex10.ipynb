# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(0)

# %%
list('ABCDE')
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
np.random.rand(3, 5)
# Out:
# array([[0.5488135 , 0.71518937, 0.60276338, 0.54488318, 0.4236548 ],
#        [0.64589411, 0.43758721, 0.891773  , 0.96366276, 0.38344152],
#        [0.79172504, 0.52889492, 0.56804456, 0.92559664, 0.07103606]])

# %%
np.round(np.random.rand(3, 5), 2)
# Out:
# array([[0.09, 0.02, 0.83, 0.78, 0.87],
#        [0.98, 0.8 , 0.46, 0.78, 0.12],
#        [0.64, 0.14, 0.94, 0.52, 0.41]])

# %%
np.vstack([list('ABCDE'), np.round(np.random.rand(3, 5), 2)] )
# Out:
# array([['A', 'B', 'C', 'D', 'E'],
#        ['0.67', '0.21', '0.13', '0.32', '0.36'],
#        ['0.57', '0.44', '0.99', '0.1', '0.21'],
#        ['0.16', '0.65', '0.25', '0.47', '0.24']], dtype='<U32')

# %%
np.vstack([list('ABCDE'), np.round(np.random.rand(3, 5), 2)] ).T
# Out:
# array([['A', '0.16', '0.37', '0.98'],
#        ['B', '0.11', '0.82', '0.47'],
#        ['C', '0.66', '0.1', '0.98'],
#        ['D', '0.14', '0.84', '0.6'],
#        ['E', '0.2', '0.1', '0.74']], dtype='<U32')

# %%
df1 = pd.DataFrame(np.vstack([list('ABCDE'), np.round(np.random.rand(3, 5), 2)] ).T,
                  columns=['C1', 'C2', 'C3', 'C4'])

# %%
df1
# Out:
#   C1    C2    C3    C4
# 0  A  0.04  0.32  0.27
# 1  B  0.28  0.41  0.52
# 2  C  0.12  0.06  0.09
# 3  D   0.3  0.69  0.58
# 4  E  0.12  0.57  0.93

# %%
df1['C1']
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# Name: C1, dtype: object

# %%
df1['C3']
# Out:
# 0    0.32
# 1    0.41
# 2    0.06
# 3    0.69
# 4    0.57
# Name: C3, dtype: object

# %%
df1
# Out:
#   C1    C2    C3    C4
# 0  A  0.04  0.32  0.27
# 1  B  0.28  0.41  0.52
# 2  C  0.12  0.06  0.09
# 3  D   0.3  0.69  0.58
# 4  E  0.12  0.57  0.93

# %%
df2 = df1.set_index('C1')

# %%
df2
# Out:
#       C2    C3    C4
# C1
# A   0.04  0.32  0.27
# B   0.28  0.41  0.52
# C   0.12  0.06  0.09
# D    0.3  0.69  0.58
# E   0.12  0.57  0.93

# %%
df2.loc['B']
# Out:
# C2    0.28
# C3    0.41
# C4    0.52
# Name: B, dtype: object

# %%
df2
# Out:
#       C2    C3    C4
# C1
# A   0.04  0.32  0.27
# B   0.28  0.41  0.52
# C   0.12  0.06  0.09
# D    0.3  0.69  0.58
# E   0.12  0.57  0.93

# %%
df3 = df2.set_index('C2')

# %%
df3
# Out:
#         C3    C4
# C2
# 0.04  0.32  0.27
# 0.28  0.41  0.52
# 0.12  0.06  0.09
# 0.3   0.69  0.58
# 0.12  0.57  0.93

# %%
df2
# Out:
#       C2    C3    C4
# C1
# A   0.04  0.32  0.27
# B   0.28  0.41  0.52
# C   0.12  0.06  0.09
# D    0.3  0.69  0.58
# E   0.12  0.57  0.93

# %%
df4 = df2.reset_index()

# %%
df4
# Out:
#   C1    C2    C3    C4
# 0  A  0.04  0.32  0.27
# 1  B  0.28  0.41  0.52
# 2  C  0.12  0.06  0.09
# 3  D   0.3  0.69  0.58
# 4  E  0.12  0.57  0.93

# %%
df2
# Out:
#       C2    C3    C4
# C1
# A   0.04  0.32  0.27
# B   0.28  0.41  0.52
# C   0.12  0.06  0.09
# D    0.3  0.69  0.58
# E   0.12  0.57  0.93

# %%
df5 = df2.reset_index(drop=True)

# %%
df5
# Out:
#      C2    C3    C4
# 0  0.04  0.32  0.27
# 1  0.28  0.41  0.52
# 2  0.12  0.06  0.09
# 3   0.3  0.69  0.58
# 4  0.12  0.57  0.93

# %%
df1
# Out:
#   C1    C2    C3    C4
# 0  A  0.04  0.32  0.27
# 1  B  0.28  0.41  0.52
# 2  C  0.12  0.06  0.09
# 3  D   0.3  0.69  0.58
# 4  E  0.12  0.57  0.93

# %%
df6 = df1.set_index('C2')

# %%
df6
# Out:
#      C1    C3    C4
# C2
# 0.04  A  0.32  0.27
# 0.28  B  0.41  0.52
# 0.12  C  0.06  0.09
# 0.3   D  0.69  0.58
# 0.12  E  0.57  0.93

# %%
df7 = df6.reset_index()

# %%
df7
# Out:
#      C2 C1    C3    C4
# 0  0.04  A  0.32  0.27
# 1  0.28  B  0.41  0.52
# 2  0.12  C  0.06  0.09
# 3   0.3  D  0.69  0.58
# 4  0.12  E  0.57  0.93

# %%
np.random.seed(0)

# %%
np.random.randn(5, 4)
# Out:
# array([[ 1.76405235,  0.40015721,  0.97873798,  2.2408932 ],
#        [ 1.86755799, -0.97727788,  0.95008842, -0.15135721],
#        [-0.10321885,  0.4105985 ,  0.14404357,  1.45427351],
#        [ 0.76103773,  0.12167502,  0.44386323,  0.33367433],
#        [ 1.49407907, -0.20515826,  0.3130677 , -0.85409574]])

# %%
np.round(np.random.randn(5, 4), 2)

# %%
df1 = pd.DataFrame( np.round(np.random.randn(5, 4), 2), 
                  columns=[['A', 'A', 'B', 'B'], 
                           ['C1', 'C2', 'C3', 'C4']])

# %%
df1
# Out:
#       A           B
#      C1    C2    C3    C4
# 0 -2.55  0.65  0.86 -0.74
# 1  2.27 -1.45  0.05 -0.19
# 2  1.53  1.47  0.15  0.38
# 3 -0.89 -1.98 -0.35  0.16
# 4  1.23  1.20 -0.39 -0.30

# %%
df1.columns
# Out:
# MultiIndex([('A', 'C1'),
#             ('A', 'C2'),
#             ('B', 'C3'),
#             ('B', 'C4')],
#            )

# %%
df1.columns.names=['Cidx1', 'Cidx2']

# %%
df1
# Out:
# Cidx1     A           B
# Cidx2    C1    C2    C3    C4
# 0     -2.55  0.65  0.86 -0.74
# 1      2.27 -1.45  0.05 -0.19
# 2      1.53  1.47  0.15  0.38
# 3     -0.89 -1.98 -0.35  0.16
# 4      1.23  1.20 -0.39 -0.30

# %%
np.random.seed(0)

# %%
np.random.randn(6, 4)
# Out:
# array([[ 1.76405235,  0.40015721,  0.97873798,  2.2408932 ],
#        [ 1.86755799, -0.97727788,  0.95008842, -0.15135721],
#        [-0.10321885,  0.4105985 ,  0.14404357,  1.45427351],
#        [ 0.76103773,  0.12167502,  0.44386323,  0.33367433],
#        [ 1.49407907, -0.20515826,  0.3130677 , -0.85409574],
#        [-2.55298982,  0.6536186 ,  0.8644362 , -0.74216502]])

# %%
np.round(np.random.randn(6, 4), 2)
# Out:
# array([[ 2.27, -1.45,  0.05, -0.19],
#        [ 1.53,  1.47,  0.15,  0.38],
#        [-0.89, -1.98, -0.35,  0.16],
#        [ 1.23,  1.2 , -0.39, -0.3 ],
#        [-1.05, -1.42, -1.71,  1.95],
#        [-0.51, -0.44, -1.25,  0.78]])

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
['id_'+str(i+1) for i in range(3)]
# Out:
# ['id_1', 'id_2', 'id_3']

# %%
['id_'+str(i+1) for i in range(3)]*2
# Out:
# ['id_1', 'id_2', 'id_3', 'id_1', 'id_2', 'id_3']

# %%
df2 = pd.DataFrame(np.round(np.random.randn(6, 4), 2), 
                  columns=[['A', 'A', 'B', 'B'],
                          ['C', 'D', 'C', 'D']],
                  index=[['M', 'M', 'M', 'F', 'F', 'F'], 
                         ['id_'+str(i+1) for i in range(3)]*2]
                  )

# %%
df2
# Out:
#       A           B
#       C     D     C     D
# 0 -1.61 -0.21 -0.90  0.39
# 1 -0.51 -1.18 -0.03  0.43
# 2  0.07  0.30 -0.63 -0.36
# 3 -0.67 -0.36 -0.81 -1.73
# 4  0.18 -0.40 -1.63  0.46
# 5 -0.91  0.05  0.73  0.13

# %%
df2
# Out:
#            A           B
#            C     D     C     D
# M id_1  1.14 -1.23  0.40 -0.68
#   id_2 -0.87 -0.58 -0.31  0.06
#   id_3 -1.17  0.90  0.47 -1.54
# F id_1  1.49  1.90  1.18 -0.18
#   id_2 -1.07  1.05 -0.40  1.22
#   id_3  0.21  0.98  0.36  0.71

# %%
df2.columns.names=['Cidx1', 'Cidx2']

# %%
df2
# Out:
# Cidx1      A           B
# Cidx2      C     D     C     D
# M id_1  1.14 -1.23  0.40 -0.68
#   id_2 -0.87 -0.58 -0.31  0.06
#   id_3 -1.17  0.90  0.47 -1.54
# F id_1  1.49  1.90  1.18 -0.18
#   id_2 -1.07  1.05 -0.40  1.22
#   id_3  0.21  0.98  0.36  0.71

# %%
df2.index.names = ['Ridx1', 'Ridx2']

# %%
df2
# Out:
# Cidx1           A           B
# Cidx2           C     D     C     D
# Ridx1 Ridx2
# M     id_1   1.14 -1.23  0.40 -0.68
#       id_2  -0.87 -0.58 -0.31  0.06
#       id_3  -1.17  0.90  0.47 -1.54
# F     id_1   1.49  1.90  1.18 -0.18
#       id_2  -1.07  1.05 -0.40  1.22
#       id_3   0.21  0.98  0.36  0.71

# %%
result = df2.stack('Cidx1')

# %%
result
# Out:
# Cidx2                 C     D
# Ridx1 Ridx2 Cidx1
# M     id_1  A      1.14 -1.23
#             B      0.40 -0.68
#       id_2  A     -0.87 -0.58
#             B     -0.31  0.06
#       id_3  A     -1.17  0.90
#             B      0.47 -1.54
# F     id_1  A      1.49  1.90
#             B      1.18 -0.18
#       id_2  A     -1.07  1.05
#             B     -0.40  1.22
#       id_3  A      0.21  0.98
#             B      0.36  0.71

# %%
df2
# Out:
# Cidx1           A           B
# Cidx2           C     D     C     D
# Ridx1 Ridx2
# M     id_1   1.14 -1.23  0.40 -0.68
#       id_2  -0.87 -0.58 -0.31  0.06
#       id_3  -1.17  0.90  0.47 -1.54
# F     id_1   1.49  1.90  1.18 -0.18
#       id_2  -1.07  1.05 -0.40  1.22
#       id_3   0.21  0.98  0.36  0.71

# %%
result = df2.stack(1)

# %%
result
# Out:
# Cidx1                 A     B
# Ridx1 Ridx2 Cidx2
# M     id_1  C      1.14  0.40
#             D     -1.23 -0.68
#       id_2  C     -0.87 -0.31
#             D     -0.58  0.06
#       id_3  C     -1.17  0.47
#             D      0.90 -1.54
# F     id_1  C      1.49  1.18
#             D      1.90 -0.18
#       id_2  C     -1.07 -0.40
#             D      1.05  1.22
#       id_3  C      0.21  0.36
#             D      0.98  0.71

# %%
df2
# Out:
# Cidx1           A           B
# Cidx2           C     D     C     D
# Ridx1 Ridx2
# M     id_1   1.14 -1.23  0.40 -0.68
#       id_2  -0.87 -0.58 -0.31  0.06
#       id_3  -1.17  0.90  0.47 -1.54
# F     id_1   1.49  1.90  1.18 -0.18
#       id_2  -1.07  1.05 -0.40  1.22
#       id_3   0.21  0.98  0.36  0.71

# %%
result = df2.unstack('Ridx2')

# %%
result
# Out:
# Cidx1     A                                   B
# Cidx2     C                 D                 C                 D
# Ridx2  id_1  id_2  id_3  id_1  id_2  id_3  id_1  id_2  id_3  id_1  id_2  id_3
# Ridx1
# F      1.49 -1.07  0.21  1.90  1.05  0.98  1.18 -0.40  0.36 -0.18  1.22  0.71
# M      1.14 -0.87 -1.17 -1.23 -0.58  0.90  0.40 -0.31  0.47 -0.68  0.06 -1.54

# %%
df2
# Out:
# Cidx1           A           B
# Cidx2           C     D     C     D
# Ridx1 Ridx2
# M     id_1   1.14 -1.23  0.40 -0.68
#       id_2  -0.87 -0.58 -0.31  0.06
#       id_3  -1.17  0.90  0.47 -1.54
# F     id_1   1.49  1.90  1.18 -0.18
#       id_2  -1.07  1.05 -0.40  1.22
#       id_3   0.21  0.98  0.36  0.71

# %%
result = df2.unstack(0)

# %%
result
# Out:
# Cidx1     A                       B
# Cidx2     C           D           C           D
# Ridx1     F     M     F     M     F     M     F     M
# Ridx2
# id_1   1.49  1.14  1.90 -1.23  1.18  0.40 -0.18 -0.68
# id_2  -1.07 -0.87  1.05 -0.58 -0.40 -0.31  1.22  0.06
# id_3   0.21 -1.17  0.98  0.90  0.36  0.47  0.71 -1.54

# %%
df1
# Out:
# Cidx1     A           B
# Cidx2    C1    C2    C3    C4
# 0     -2.55  0.65  0.86 -0.74
# 1      2.27 -1.45  0.05 -0.19
# 2      1.53  1.47  0.15  0.38
# 3     -0.89 -1.98 -0.35  0.16
# 4      1.23  1.20 -0.39 -0.30

# %%
df1['B']
# Out:
# Cidx2    C3    C4
# 0      0.86 -0.74
# 1      0.05 -0.19
# 2      0.15  0.38
# 3     -0.35  0.16
# 4     -0.39 -0.30

# %%
df1['C1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\codelab\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'C1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-5795bfc3da8e> in <module>
# ----> 1 df1['C1']
#
# ...

# %%
df1[('A', 'C1')]
# Out:
# 0   -2.55
# 1    2.27
# 2    1.53
# 3   -0.89
# 4    1.23
# Name: (A, C1), dtype: float64

# %%
df1
# Out:
# Cidx1     A           B
# Cidx2    C1    C2    C3    C4
# 0     -2.55  0.65  0.86 -0.74
# 1      2.27 -1.45  0.05 -0.19
# 2      1.53  1.47  0.15  0.38
# 3     -0.89 -1.98 -0.35  0.16
# 4      1.23  1.20 -0.39 -0.30

# %%
df1.iloc[0, 2]
# Out:
# 0.86

# %%
df1
# Out:
# Cidx1     A           B
# Cidx2    C1    C2    C3    C4
# 0     -2.55  0.65  0.86 -0.74
# 1      2.27 -1.45  0.05 -0.19
# 2      1.53  1.47  0.15  0.38
# 3     -0.89 -1.98 -0.35  0.16
# 4      1.23  1.20 -0.39 -0.30

# %%
df1['A']
# Out:
# Cidx2    C1    C2
# 0     -2.55  0.65
# 1      2.27 -1.45
# 2      1.53  1.47
# 3     -0.89 -1.98
# 4      1.23  1.20

# %%
df1['C1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\codelab\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'C1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-5795bfc3da8e> in <module>
# ----> 1 df1['C1']
#
# ...

# %%
df2
# Out:
# Cidx1           A           B
# Cidx2           C     D     C     D
# Ridx1 Ridx2
# M     id_1   1.14 -1.23  0.40 -0.68
#       id_2  -0.87 -0.58 -0.31  0.06
#       id_3  -1.17  0.90  0.47 -1.54
# F     id_1   1.49  1.90  1.18 -0.18
#       id_2  -1.07  1.05 -0.40  1.22
#       id_3   0.21  0.98  0.36  0.71

# %%
result = df2.loc[('M', 'id_1'),('A', 'C')]

# %%
result
# Out:
# 1.14

# %%
result = df2.loc[:,('A', 'C')]

# %%
result
# Out:
# Ridx1  Ridx2
# M      id_1     1.14
#        id_2    -0.87
#        id_3    -1.17
# F      id_1     1.49
#        id_2    -1.07
#        id_3     0.21
# Name: (A, C), dtype: float64

# %%
df2
# Out:
# Cidx1           A           B
# Cidx2           C     D     C     D
# Ridx1 Ridx2
# M     id_1   1.14 -1.23  0.40 -0.68
#       id_2  -0.87 -0.58 -0.31  0.06
#       id_3  -1.17  0.90  0.47 -1.54
# F     id_1   1.49  1.90  1.18 -0.18
#       id_2  -1.07  1.05 -0.40  1.22
#       id_3   0.21  0.98  0.36  0.71

# %%
result = df2.loc[('M', 'id_1'),:]

# %%
result
# Out:
# Cidx1  Cidx2
# A      C        1.14
#        D       -1.23
# B      C        0.40
#        D       -0.68
# Name: (M, id_1), dtype: float64

# %%
df2.loc[('All', 'All'), :] = df2.sum()

# %%
df2
# Out:
# Cidx1           A           B
# Cidx2           C     D     C     D
# Ridx1 Ridx2
# M     id_1   1.14 -1.23  0.40 -0.68
#       id_2  -0.87 -0.58 -0.31  0.06
#       id_3  -1.17  0.90  0.47 -1.54
# F     id_1   1.49  1.90  1.18 -0.18
#       id_2  -1.07  1.05 -0.40  1.22
#       id_3   0.21  0.98  0.36  0.71
# All   All   -0.27  3.02  1.70 -0.41

# %%
df2
# Out:
# Cidx1           A           B
# Cidx2           C     D     C     D
# Ridx1 Ridx2
# M     id_1   1.14 -1.23  0.40 -0.68
#       id_2  -0.87 -0.58 -0.31  0.06
#       id_3  -1.17  0.90  0.47 -1.54
# F     id_1   1.49  1.90  1.18 -0.18
#       id_2  -1.07  1.05 -0.40  1.22
#       id_3   0.21  0.98  0.36  0.71
# All   All   -0.27  3.02  1.70 -0.41

# %%
df3 = df2.swaplevel('Ridx1', 'Ridx2')

# %%
df3
# Out:
# Cidx1           A           B
# Cidx2           C     D     C     D
# Ridx2 Ridx1
# id_1  M      1.14 -1.23  0.40 -0.68
# id_2  M     -0.87 -0.58 -0.31  0.06
# id_3  M     -1.17  0.90  0.47 -1.54
# id_1  F      1.49  1.90  1.18 -0.18
# id_2  F     -1.07  1.05 -0.40  1.22
# id_3  F      0.21  0.98  0.36  0.71
# All   All   -0.27  3.02  1.70 -0.41

# %%
df2
# Out:
# Cidx1           A           B
# Cidx2           C     D     C     D
# Ridx1 Ridx2
# M     id_1   1.14 -1.23  0.40 -0.68
#       id_2  -0.87 -0.58 -0.31  0.06
#       id_3  -1.17  0.90  0.47 -1.54
# F     id_1   1.49  1.90  1.18 -0.18
#       id_2  -1.07  1.05 -0.40  1.22
#       id_3   0.21  0.98  0.36  0.71
# All   All   -0.27  3.02  1.70 -0.41

# %%
df4 = df2.swaplevel('Cidx1', 'Cidx2', axis=1)

# %%
df4
# Out:
# Cidx2           C     D     C     D
# Cidx1           A     A     B     B
# Ridx1 Ridx2
# M     id_1   1.14 -1.23  0.40 -0.68
#       id_2  -0.87 -0.58 -0.31  0.06
#       id_3  -1.17  0.90  0.47 -1.54
# F     id_1   1.49  1.90  1.18 -0.18
#       id_2  -1.07  1.05 -0.40  1.22
#       id_3   0.21  0.98  0.36  0.71
# All   All   -0.27  3.02  1.70 -0.41

# %%
df3
# Out:
# Cidx1           A           B
# Cidx2           C     D     C     D
# Ridx2 Ridx1
# id_1  M      1.14 -1.23  0.40 -0.68
# id_2  M     -0.87 -0.58 -0.31  0.06
# id_3  M     -1.17  0.90  0.47 -1.54
# id_1  F      1.49  1.90  1.18 -0.18
# id_2  F     -1.07  1.05 -0.40  1.22
# id_3  F      0.21  0.98  0.36  0.71
# All   All   -0.27  3.02  1.70 -0.41

# %%
result = df3.sort_index(level=0, axis=0)

# %%
result
# Out:
# Cidx1           A           B
# Cidx2           C     D     C     D
# Ridx2 Ridx1
# All   All   -0.27  3.02  1.70 -0.41
# id_1  F      1.49  1.90  1.18 -0.18
#       M      1.14 -1.23  0.40 -0.68
# id_2  F     -1.07  1.05 -0.40  1.22
#       M     -0.87 -0.58 -0.31  0.06
# id_3  F      0.21  0.98  0.36  0.71
#       M     -1.17  0.90  0.47 -1.54

# %%
df4
# Out:
# Cidx2           C     D     C     D
# Cidx1           A     A     B     B
# Ridx1 Ridx2
# M     id_1   1.14 -1.23  0.40 -0.68
#       id_2  -0.87 -0.58 -0.31  0.06
#       id_3  -1.17  0.90  0.47 -1.54
# F     id_1   1.49  1.90  1.18 -0.18
#       id_2  -1.07  1.05 -0.40  1.22
#       id_3   0.21  0.98  0.36  0.71
# All   All   -0.27  3.02  1.70 -0.41

# %%
result = df4.sort_index(axis=1, level=0)

# %%
result
# Out:
# Cidx2           C           D
# Cidx1           A     B     A     B
# Ridx1 Ridx2
# M     id_1   1.14  0.40 -1.23 -0.68
#       id_2  -0.87 -0.31 -0.58  0.06
#       id_3  -1.17  0.47  0.90 -1.54
# F     id_1   1.49  1.18  1.90 -0.18
#       id_2  -1.07 -0.40  1.05  1.22
#       id_3   0.21  0.36  0.98  0.71
# All   All   -0.27  1.70  3.02 -0.41
