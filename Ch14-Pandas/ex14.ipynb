# %%
import pandas as pd

# %%
df1 = pd.read_table('samplefile1.txt', sep='\s+')

# %%
df1
# Out:
#         |c1|c2|c3
# 0    0|1|1.11|one
# 1    1|2|2.22|two
# 2  2|3|3.33|three

# %%
df2 = pd.read_table('samplefile2.txt', sep="\s+")

# %%
df2
# Out:
#                        파일명: samplefile2.txt
# 파일    포멧         설정:    텍스트              파일
# 만든사람: codedragon NaN    NaN             NaN
# 1     1.11       one    NaN             NaN
# 2     2.22       two    NaN             NaN
# 3     3.33       three  NaN             NaN

# %%
df2 = pd.read_csv('samplefile2.txt')

# %%
df2
# Out:
#   파일명: samplefile2.txt
# 0     파일 포멧 설정: 텍스트 파일
# 1     만든사람: codedragon
# 2         1\t1.11\tone
# 3         2\t2.22\ttwo
# 4       3\t3.33\tthree

# %%
df2 = pd.read_csv('samplefile2.txt', sep='\s+', skiprows=[0, 1, 2])

# %%
df2
# Out:
#    1  1.11    one
# 0  2  2.22    two
# 1  3  3.33  three

# %%
import pandas as pd

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table', 
                 header=0, index_col=0)

# %%
df
# Out:
# [Empty DataFrame
#  Columns: []
#  Index: [Main topics, Bids Boycotts Ceremonies Charter Host cities IFs IOC Medal Medal tables Medalists NOCs Pierre de Coubertin medal Scandals and controversies Sports Symbols Television Torch relays Venues Women participation, Games, Summer Winter Summer Paralympic Winter Paralympic Youth Deaflympics Special African American Asian European Pacific Ancient Intercalated, vte],
#                                               Summer Games  Summer Games.1  \
#  Team (IOC code)                                         №             NaN
#  Afghanistan (AFG)                                      14             0.0
#  Algeria (ALG)                                          13             5.0
#  Argentina (ARG)                                        24            21.0
#  Armenia (ARM)                                           6             2.0
#  ...                                                   ...             ...
# ...

# %%
df[0]
# Out:
# Empty DataFrame
# Columns: []
# Index: [Main topics, Bids Boycotts Ceremonies Charter Host cities IFs IOC Medal Medal tables Medalists NOCs Pierre de Coubertin medal Scandals and controversies Sports Symbols Television Torch relays Venues Women participation, Games, Summer Winter Summer Paralympic Winter Paralympic Youth Deaflympics Special African American Asian European Pacific Ancient Intercalated, vte]

# %%
df[1]
# Out:
#                                              Summer Games  Summer Games.1  \
# Team (IOC code)                                         №             NaN
# Afghanistan (AFG)                                      14             0.0
# Algeria (ALG)                                          13             5.0
# Argentina (ARG)                                        24            21.0
# Armenia (ARM)                                           6             2.0
# ...                                                   ...             ...
# Zimbabwe (ZIM) [ZIM]                                   13             3.0
# Independent Olympic Athletes (IOA) [IOA]                3             1.0
# Independent Olympic Participants (IOP) [IOP]            1             0.0
# Mixed team (ZZX) [ZZX]                                  3             8.0
# Totals                                                 28          5115.0
#
#                                               Summer Games.2  Summer Games.3  \
# ...

# %%
df[2]
# Out:
#                                   № Summer  № Winter  № Games
# Team (IOC code)
# Albania (ALB)                            8         4       12
# American Samoa (ASA)                     8         1        9
# Andorra (AND)                           11        12       23
# Angola (ANG)                             9         0        9
# Antigua and Barbuda (ANT)               10         0       10
# ...                                    ...       ...      ...
# Republic of China (ROC) [ROC]            3         0        3
# Saar (SAA) [SAA]                         1         0        1
# North Yemen (YAR) [YAR]                  2         0        2
# South Yemen (YMD) [YMD]                  1         0        1
# Refugee Olympic Team (ROT) [ROT]         1         0        1
#
# [79 rows x 3 columns]

# %%
df[1].iloc[:, :5]
# Out:
#                                              Summer Games  Summer Games.1  \
# Team (IOC code)                                         №             NaN
# Afghanistan (AFG)                                      14             0.0
# Algeria (ALG)                                          13             5.0
# Argentina (ARG)                                        24            21.0
# Armenia (ARM)                                           6             2.0
# ...                                                   ...             ...
# Zimbabwe (ZIM) [ZIM]                                   13             3.0
# Independent Olympic Athletes (IOA) [IOA]                3             1.0
# Independent Olympic Participants (IOP) [IOP]            1             0.0
# Mixed team (ZZX) [ZZX]                                  3             8.0
# Totals                                                 28          5115.0
#
#                                               Summer Games.2  Summer Games.3  \
# ...

# %%
summer = df[1].iloc[:, :5]

# %%
summer
# Out:
#                                              Summer Games  Summer Games.1  \
# Team (IOC code)                                         №             NaN
# Afghanistan (AFG)                                      14             0.0
# Algeria (ALG)                                          13             5.0
# Argentina (ARG)                                        24            21.0
# Armenia (ARM)                                           6             2.0
# ...                                                   ...             ...
# Zimbabwe (ZIM) [ZIM]                                   13             3.0
# Independent Olympic Athletes (IOA) [IOA]                3             1.0
# Independent Olympic Participants (IOP) [IOP]            1             0.0
# Mixed team (ZZX) [ZZX]                                  3             8.0
# Totals                                                 28          5115.0
#
#                                               Summer Games.2  Summer Games.3  \
# ...

# %%
summer.columns
# Out:
# Index(['Summer Games', 'Summer Games.1', 'Summer Games.2', 'Summer Games.3',
#        'Summer Games.4'],
#       dtype='object')

# %%
summer.columns = ['경기수', '금', '은', '동', '계']

# %%
summer
# Out:
#                                              경기수       금       은       동  \
# Team (IOC code)                                №     NaN     NaN     NaN
# Afghanistan (AFG)                             14     0.0     0.0     2.0
# Algeria (ALG)                                 13     5.0     4.0     8.0
# Argentina (ARG)                               24    21.0    25.0    28.0
# Armenia (ARM)                                  6     2.0     6.0     6.0
# ...                                           ..     ...     ...     ...
# Zimbabwe (ZIM) [ZIM]                          13     3.0     4.0     1.0
# Independent Olympic Athletes (IOA) [IOA]       3     1.0     0.0     1.0
# Independent Olympic Participants (IOP) [IOP]   1     0.0     1.0     2.0
# Mixed team (ZZX) [ZZX]                         3     8.0     5.0     4.0
# Totals                                        28  5115.0  5081.0  5486.0
#
#                                                   계
# ...

# %%
out = open('output.txt', 'w', encoding='utf8')

# %%
print(summer, file=out)

# %%
out.close()

# %%
summer
# Out:
#                                              경기수       금       은       동  \
# Team (IOC code)                                №     NaN     NaN     NaN
# Afghanistan (AFG)                             14     0.0     0.0     2.0
# Algeria (ALG)                                 13     5.0     4.0     8.0
# Argentina (ARG)                               24    21.0    25.0    28.0
# Armenia (ARM)                                  6     2.0     6.0     6.0
# ...                                           ..     ...     ...     ...
# Zimbabwe (ZIM) [ZIM]                          13     3.0     4.0     1.0
# Independent Olympic Athletes (IOA) [IOA]       3     1.0     0.0     1.0
# Independent Olympic Participants (IOP) [IOP]   1     0.0     1.0     2.0
# Mixed team (ZZX) [ZZX]                         3     8.0     5.0     4.0
# Totals                                        28  5115.0  5081.0  5486.0
#
#                                                   계
# ...

# %%
summer.sort_values('금', ascending=False)
# Out:
#                                         경기수       금       은       동      계
# Totals                                   28  5115.0  5081.0  5486.0  15682
# United States (USA) [P] [Q] [R] [Z] [F]  27  1022.0   795.0   705.0   2522
# Soviet Union (URS) [URS]                  9   395.0   319.0   296.0   1010
# Great Britain (GBR) [GBR] [Z]            28   263.0   295.0   293.0    851
# China (CHN) [CHN]                        10   224.0   167.0   155.0    546
# ...                                      ..     ...     ...     ...    ...
# Eritrea (ERI)                             5     0.0     0.0     1.0      1
# Serbia and Montenegro (SCG) [SCG]         1     0.0     2.0     0.0      2
# Djibouti (DJI) [B]                        8     0.0     0.0     1.0      1
# Afghanistan (AFG)                        14     0.0     0.0     2.0      2
# Team (IOC code)                           №     NaN     NaN     NaN  Total
#
# [154 rows x 5 columns]

# %%
out = open('output.txt', 'w', encoding='UTF8')

# %%
print(summer.sort_values('금', ascending=False), file=out)

# %%
out.close()

# %%
summer.to_excel('output.xlsx')

# %%
summer.to_csv('output.csv')

# %%
ssummer = pd.read_csv('output.csv')

# %%
ssummer
# Out:
#                                        Unnamed: 0 경기수       금       은       동  \
# 0                                 Team (IOC code)   №     NaN     NaN     NaN
# 1                               Afghanistan (AFG)  14     0.0     0.0     2.0
# 2                                   Algeria (ALG)  13     5.0     4.0     8.0
# 3                                 Argentina (ARG)  24    21.0    25.0    28.0
# 4                                   Armenia (ARM)   6     2.0     6.0     6.0
# ..                                            ...  ..     ...     ...     ...
# 149                          Zimbabwe (ZIM) [ZIM]  13     3.0     4.0     1.0
# 150      Independent Olympic Athletes (IOA) [IOA]   3     1.0     0.0     1.0
# 151  Independent Olympic Participants (IOP) [IOP]   1     0.0     1.0     2.0
# 152                        Mixed team (ZZX) [ZZX]   3     8.0     5.0     4.0
# 153                                        Totals  28  5115.0  5081.0  5486.0
#
#          계
# 0    Total
# ...

# %%
from pandas_datareader.data import DataReader

# %%
import datetime

# %%
dt_start = datetime.datetime(2015, 1, 1)

# %%
dt_start
# Out:
# datetime.datetime(2015, 1, 1, 0, 0)

# %%
dt_end = '2016, 6, 30'

# %%
dt_end
# Out:
# '2016, 6, 30'

# %%
gdp = DataReader('GDP', 'fred')

# %%
gdp
# Out:
#                   GDP
# DATE
# 2015-04-01  18219.405
# 2015-07-01  18344.713
# 2015-10-01  18350.825
# 2016-01-01  18424.283
# 2016-04-01  18637.253
# 2016-07-01  18806.743
# 2016-10-01  18991.883
# 2017-01-01  19190.431
# 2017-04-01  19356.649
# 2017-07-01  19611.704
# 2017-10-01  19918.910
# 2018-01-01  20163.159
# 2018-04-01  20510.177
# 2018-07-01  20749.752
# 2018-10-01  20897.804
# 2019-01-01  21098.827
# 2019-04-01  21340.267
# 2019-07-01  21542.540
# 2019-10-01  21734.266

# %%
gdp = DataReader('GDP', 'fred', dt_start, dt_end)

# %%
gdp
# Out:
#                   GDP
# DATE
# 2015-01-01  17984.178
# 2015-04-01  18219.405
# 2015-07-01  18344.713
# 2015-10-01  18350.825
# 2016-01-01  18424.283
# 2016-04-01  18637.253

# %%
gdp.head()
# Out:
#                   GDP
# DATE
# 2015-01-01  17984.178
# 2015-04-01  18219.405
# 2015-07-01  18344.713
# 2015-10-01  18350.825
# 2016-01-01  18424.283

# %%
gdp.tail()
# Out:
#                   GDP
# DATE
# 2015-04-01  18219.405
# 2015-07-01  18344.713
# 2015-10-01  18350.825
# 2016-01-01  18424.283
# 2016-04-01  18637.253

# %%
len(gdp)
# Out:
# 6

# %%
len(gdp)
# Out:
# 19

# %%
type(gdp)
# Out:
# pandas.core.frame.DataFrame

# %%
gdp.columns
# Out:
# Index(['GDP'], dtype='object')

# %%
gdp.index
# Out:
# DatetimeIndex(['2015-04-01', '2015-07-01', '2015-10-01', '2016-01-01',
#                '2016-04-01', '2016-07-01', '2016-10-01', '2017-01-01',
#                '2017-04-01', '2017-07-01', '2017-10-01', '2018-01-01',
#                '2018-04-01', '2018-07-01', '2018-10-01', '2019-01-01',
#                '2019-04-01', '2019-07-01', '2019-10-01'],
#               dtype='datetime64[ns]', name='DATE', freq=None)

# %%
df = DataReader(['CPIAUCSL', 'CPILFESL'], 'fred', dt_start, dt_end)

# %%
df
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2015-01-01   234.747   239.811
# 2015-02-01   235.342   240.172
# 2015-03-01   235.976   240.755
# 2015-04-01   236.222   241.346
# 2015-05-01   237.001   241.688
# 2015-06-01   237.657   242.064
# 2015-07-01   238.034   242.565
# 2015-08-01   238.033   242.817
# 2015-09-01   237.498   243.316
# 2015-10-01   237.733   243.768
# 2015-11-01   238.017   244.241
# 2015-12-01   237.761   244.547
# 2016-01-01   237.827   245.075
# 2016-02-01   237.514   245.644
# 2016-03-01   237.990   245.964
# 2016-04-01   238.835   246.467
# 2016-05-01   239.440   247.036
# 2016-06-01   240.144   247.435

# %%
len(df)
# Out:
# 18

# %%
df.head()
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2015-01-01   234.747   239.811
# 2015-02-01   235.342   240.172
# 2015-03-01   235.976   240.755
# 2015-04-01   236.222   241.346
# 2015-05-01   237.001   241.688

# %%
df.tail()
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2016-02-01   237.514   245.644
# 2016-03-01   237.990   245.964
# 2016-04-01   238.835   246.467
# 2016-05-01   239.440   247.036
# 2016-06-01   240.144   247.435

# %%
df.columns
# Out:
# Index(['CPIAUCSL', 'CPILFESL'], dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01',
#                '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01',
#                '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01',
#                '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01',
#                '2016-05-01', '2016-06-01'],
#               dtype='datetime64[ns]', name='DATE', freq=None)
